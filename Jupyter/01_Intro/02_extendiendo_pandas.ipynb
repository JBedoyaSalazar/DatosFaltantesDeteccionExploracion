# %% [markdown]
# # Extendiendo Pandas
#
# Demostración del accessor `.missing` para resumir datos faltantes.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd

from src.pandas_accessors import MissingMethods

# %%
df = pd.DataFrame({
    'a': list('asdkajidwj'),
    'b': range(10),
})
df.iloc[2:5, 0] = None
df.iloc[6:7, 1] = None
df
# Out:
#      a    b
# 0    a  0.0
# 1    s  1.0
# 2  NaN  2.0
# 3  NaN  3.0
# 4  NaN  4.0
# 5    j  5.0
# 6    i  NaN
# 7    d  7.0
# 8    w  8.0
# 9    j  9.0

# %% [markdown]
# ## Resumen de valores faltantes

# %%
print(f"Valores faltantes: {df.missing.number_missing()}")
print(f"Valores completos: {df.missing.number_complete()}")
print(f"Sumatoria valores faltantes: \n{df.missing.missing_variable_summary()}")
# Out:
# Valores faltantes: 4
# Valores completos: 16
# Sumatoria valores faltantes:
#   variable  n_missing  n_cases  pct_missing
# 0        a          3       10         30.0
# 1        b          1       10         10.0
